# %%
import re
import bs4
from bs4 import BeautifulSoup
from requests import get

import pandas as pd
import sinta_scraper as sinta

import numpy as np

# %%
def page_extractor(soup):
    result = []
    for num, i in enumerate(soup.select(".text-blue")): #get first item
        #get name and sinta id
        name = i.text.strip()
        author_id = re.findall(r'\d+', i['href'])[0]
        # get affiliation and NIDN
        for x in i.find_next('dd'):
            affil_name = x.contents[0] 
            NIDN = x.find_next('dd').contents[2].replace(' : ', '')
        # Get expertise
        areas = [] # empty container
        expertise1 = i.find_next('a', {'class':"area-item-small"}) # get first expertise
        ctr = 0 # helper counter
        while ctr < 3 and isinstance(expertise1, bs4.element.Tag): # loop until NoneType & max 3 expertise
            areas.append(expertise1.contents[0])
            expertise1 = expertise1.find_next('a') # get next expertise
            try:
                if expertise1['class'][0] == 'area-item-small': # if expertise feature, continue
                    ctr = ctr + 1
                else: # if not expertise feature pass
                    ctr = 3
            except KeyError:
                ctr = 3
        
        result_data = {'id': author_id,
                       'name': name,
                       'NIDN' : NIDN,
                       'affiliation': affil_name,
                       'areas': areas 
                       }
        result.append(result_data)
    return result

def search_author(term):
    term = term.replace(' ','+') #format search for url
    p_ctr = 1 # init page
    
    # load html from first page
    url = f'https://sinta.ristekbrin.go.id/authors?page={p_ctr}&q={term}&search=2&ag=&sort=year2&view='
    html = get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    
    # calculate how many pages
    page = soup.find('caption').contents
    page = [int(s) for s in page[0].split() if s.isdigit()]
    p_max = page[1]
    
    # get result from first page
    result = []
    data = page_extractor(soup)
    [result.append(dic) for dic in data]
    
    if p_max == 1:
        pass
    else:
        while p_ctr < (p_max + 1):
            p_ctr = p_ctr + 1
            print(f'{term}: retrieving page {p_ctr-1} of {p_max}')
            url = f'https://sinta.ristekbrin.go.id/authors?page={p_ctr}&q={term}&search=2&ag=&sort=year2&view='
            #print(url)
            html = get(url)
            soup = BeautifulSoup(html.content, 'html.parser')
            data = page_extractor(soup)
            [result.append(dic) for dic in data]
    return result

# %%
# get authors of from biologi department S1, S2, S3
affil_name = 'ipb'
affil_name_long = 'Institut Pertanian Bogor'
affil_id = '428'
dept_id = [46002, 54107, 54113, 54007, 46102, 46004, 47101, 54153, 47202, 46104, 54208, 46103, 46101, 54132, 54053, 46003, 46201, 54032]

SINTA = pd.DataFrame()
for de in dept_id:
    data = sinta.dept_authors(de, affil_id)
    data = pd.DataFrame(data)
    #print(de, data)
    data.loc[:, 'department'] = de
    SINTA = SINTA.append(data)
SINTA['NIDN'] = np.nan
ALL = SINTA

# Load data in manual
#MANUAL = pd.read_csv('../data/ITB/data_NIDN-versi-sinta.txt', index_col=0, dtype=str)

# Merge both in Manual and in SINTA
#MERGE = MANUAL.merge(SINTA, left_on='name', right_on='name')

# Not listed yet in SINTA
#mask = MANUAL['name'].isin(SINTA.name)
#not_listed = MANUAL[~mask]

# Append all data together
#ALL = MERGE.append(not_listed)

# Filter retired faculty member
RETIRED = pd.read_csv(f'../data/{affil_name.upper()}/{affil_name}_bio_retired.txt')
mask = ALL.name.isin(RETIRED.Retired)
ALL = ALL[~mask]
#ALL

#ALL.loc[ALL[ALL.id.isnull()].index, 'id'] = ALL.loc[ALL[ALL.id.isnull()].index, 'id_manual']
#ALL = ALL.drop(columns=['id_manual'])


ALL = ALL.sort_values(by=['name']).reset_index(drop=True)
ALL.to_csv(f'../data/{affil_name.upper()}/all.csv')
ALL
# Out:
#           id                             name  department  NIDN
# 0    6186794              Abdul Haris Mustari       54153   NaN
# 1    5996964                Achmad Farajallah       46002   NaN
# 2    6000226               Agus Ghautsun Niam       54208   NaN
# 3    6038006                      Agus Hikmat       54153   NaN
# 4    5985693             Agus Priyono Kartono       54053   NaN
# ..       ...                              ...         ...   ...
# 112  6165395  Yohana Caecilia Sulistyaningsih       46103   NaN
# 113    36148            Yohanes Aris Purwanto       54208   NaN
# 114  5988733     Yudiwanti Wahyu Endro Kusumo       54007   NaN
# 115  5976282     Yuliana Maria Diah Ratnadewi       46003   NaN
# 116  5982915                    Yulin Lestari       46104   NaN
#
# [117 rows x 4 columns]

# %% [raw]
# # Missing SINTA ID
# missing_SINTAID = ALL[pd.isnull(ALL.id)]
# nama = missing_SINTAID.name
# output_missing_SINTAID = pd.DataFrame()
# for i in nama:
#     print(i)
#     data = search_author(i)
#     data = pd.DataFrame(data)
#     data = data[data.affiliation == 'Institut Teknologi Bandung']
#     output_missing_SINTAID = output_missing_SINTAID.append(data)
# output_missing_SINTAID

# %%
# Missing NIDN
missing_NIDN = ALL[pd.isnull(ALL.NIDN)]
nama = missing_NIDN.name
output_missing_NIDN = pd.DataFrame()
for i in nama:
    print(i)
    data = search_author(i)
    data = pd.DataFrame(data)
    data = data[data.affiliation == affil_name_long]
    output_missing_NIDN = output_missing_NIDN.append(data)
output_missing_NIDN
# Out:
# Abdul Haris Mustari
# Achmad Farajallah
# Agus Ghautsun Niam
# Agus Hikmat
# Agus Priyono Kartono
# Agus Sutejo
# Akhmad Endang Zainal Hasan
# Amrozi
# Ani Mardiastuti
# Anja Meryandini
# Antonius Suwanto
# Aris Tjahjoleksono
# Aris Tri Wahyudi
# Awang Maharijaya
# Bambang Purwantara
# Bambang Suryobroto
# Berry Juliandi
# Burhanuddin Masyud
# Darda Efendi
# Dede Aulia Rahman
# Dede Setiadi
# Dedy Duryadi Solihin
# Desrial
# Desta Wirnas
# Dewi Sukma
# Didy Sopandie
# Dimas Andrianto
# Dinar Tri Soelistyowati
# Djarot Sasongko Hami Seno
# Dorly
# Dwi Andreas Santosa
# Edy Hartulistiyoso
# Gatot Pramuhadi
# Gayuh Rahayu
# Gunawan Djajakirana
# Hadisunarso
# Hajrial Aswidinnoor
# Hamim
# Hamim: retrieving page 1 of 5
# Hamim: retrieving page 2 of 5
# Hamim: retrieving page 3 of 5
# Hamim: retrieving page 4 of 5
# Hamim: retrieving page 5 of 5
# Hasim
# Hasim: retrieving page 1 of 4
# Hasim: retrieving page 2 of 4
# Hasim: retrieving page 3 of 4
# Hasim: retrieving page 4 of 4
# Hilda Akmal
# Hirmas Fuady Putra
# Husnawati
# I Made Artika
# Ibnul Qayim
# Iman Rusmana
# Iman Supriatna
# Ivan Permana Putra
# Jarwadi Budi Hernowo
# Jepri Agung Priyanto
# Judi
# Judi: retrieving page 1 of 9
# Judi: retrieving page 2 of 9
# Judi: retrieving page 3 of 9
# Judi: retrieving page 4 of 9
# Judi: retrieving page 5 of 9
# Judi: retrieving page 6 of 9
# Judi: retrieving page 7 of 9
# Judi: retrieving page 8 of 9
# Judi: retrieving page 9 of 9
# Kanthi  Arum Widayati
# Khaswar Syamsu
# Laksmi Ambarsari
# Lenny Saulia
# Ligaya Ita Tumbelaka
# Lilis Sucahyo
# Lisdar A Manaf
# Liyantono
# Mafrikhul Muttaqin
# Maria Bintang
# Mega Safithri
# Miftahudin
# Mirza Dikari Kusrini
# Mohamad Agus Setiadi
# Mokhamad Fakhrul Ulum
# Muhamad Syukur
# Muhamad Yulianto
# Mulyorini Rahayuningsih
# Nampiah
# Ni Made Armini Wiendi
# Ni Wayan Kurniani Karja
# Nisa Rachmania
# Nunik Sri Ariyanti
# Nurul Khumaida
# Nyoto Santoso
# Prayoga Suryadarma
# Puji Rianti
# Puspa Julistia Puspita
# R Harry Soehartono
# R Iis Arifiantini
# Rahayu Widyastuti
# Rd Roro Dyah Perwitasari
# Rika Indri Astuti
# Rika Raffiudin
# Rita Megia
# Sintho Wahyuning Ardie
# Slamet Widodo
# Slamet+Widodo: retrieving page 1 of 2
# Slamet+Widodo: retrieving page 2 of 2
# Sobir
# Sobir: retrieving page 1 of 2
# Sobir: retrieving page 2 of 2
# Sri Budiarti
# Sri Endah Agustina
# Sri Listiyowati
# Sudarsono
# Sudarsono: retrieving page 1 of 5
# Sudarsono: retrieving page 2 of 5
# Sudarsono: retrieving page 3 of 5
# Sudarsono: retrieving page 4 of 5
# Sudarsono: retrieving page 5 of 5
# Suharsono
# Suharsono: retrieving page 1 of 3
# Suharsono: retrieving page 2 of 3
# Suharsono: retrieving page 3 of 3
# Supriyanto
# Supriyanto: retrieving page 1 of 13
# Supriyanto: retrieving page 2 of 13
# Supriyanto: retrieving page 3 of 13
# Supriyanto: retrieving page 4 of 13
# Supriyanto: retrieving page 5 of 13
# Supriyanto: retrieving page 6 of 13
# Supriyanto: retrieving page 7 of 13
# Supriyanto: retrieving page 8 of 13
# Supriyanto: retrieving page 9 of 13
# Supriyanto: retrieving page 10 of 13
# Supriyanto: retrieving page 11 of 13
# Supriyanto: retrieving page 12 of 13
# Supriyanto: retrieving page 13 of 13
# Suryani
# Suryani: retrieving page 1 of 37
# Suryani: retrieving page 2 of 37
# Suryani: retrieving page 3 of 37
# Suryani: retrieving page 4 of 37
# Suryani: retrieving page 5 of 37
# Suryani: retrieving page 6 of 37
# Suryani: retrieving page 7 of 37
# Suryani: retrieving page 8 of 37
# Suryani: retrieving page 9 of 37
# Suryani: retrieving page 10 of 37
# Suryani: retrieving page 11 of 37
# Suryani: retrieving page 12 of 37
# Suryani: retrieving page 13 of 37
# Suryani: retrieving page 14 of 37
# Suryani: retrieving page 15 of 37
# Suryani: retrieving page 16 of 37
# Suryani: retrieving page 17 of 37
# Suryani: retrieving page 18 of 37
# Suryani: retrieving page 19 of 37
# Suryani: retrieving page 20 of 37
# Suryani: retrieving page 21 of 37
# Suryani: retrieving page 22 of 37
# Suryani: retrieving page 23 of 37
# Suryani: retrieving page 24 of 37
# Suryani: retrieving page 25 of 37
# Suryani: retrieving page 26 of 37
# Suryani: retrieving page 27 of 37
# Suryani: retrieving page 28 of 37
# Suryani: retrieving page 29 of 37
# Suryani: retrieving page 30 of 37
# Suryani: retrieving page 31 of 37
# Suryani: retrieving page 32 of 37
# Suryani: retrieving page 33 of 37
# Suryani: retrieving page 34 of 37
# Suryani: retrieving page 35 of 37
# Suryani: retrieving page 36 of 37
# Suryani: retrieving page 37 of 37
# Sutrisno
# Sutrisno: retrieving page 1 of 18
# Sutrisno: retrieving page 2 of 18
# Sutrisno: retrieving page 3 of 18
# Sutrisno: retrieving page 4 of 18
# Sutrisno: retrieving page 5 of 18
# Sutrisno: retrieving page 6 of 18
# Sutrisno: retrieving page 7 of 18
# Sutrisno: retrieving page 8 of 18
# Sutrisno: retrieving page 9 of 18
# Sutrisno: retrieving page 10 of 18
# Sutrisno: retrieving page 11 of 18
# Sutrisno: retrieving page 12 of 18
# Sutrisno: retrieving page 13 of 18
# Sutrisno: retrieving page 14 of 18
# Sutrisno: retrieving page 15 of 18
# Sutrisno: retrieving page 16 of 18
# Sutrisno: retrieving page 17 of 18
# Sutrisno: retrieving page 18 of 18
# Syaefudin
# Syaefudin: retrieving page 1 of 2
# Syaefudin: retrieving page 2 of 2
# Syamsul Falah
# Syarifah Iis Aisyah
# Taruni Sri Prawasti
# Tatik Chikmawati
# Tri Atmowidi
# Tri Heru Widarto
# Triadiati
# Trikoesoemaningtyas
# Ukhradiya Magharaniq Safira Purwanto
# Waras Nurcholis
# Willy Bayuardi Suwarno
# Winarso Drajad Widodo
# Windra Priawandiputra
# Yanto Santosa
# Yeni Aryati Mulyani
# Yohana Caecilia Sulistyaningsih
# Yohanes Aris Purwanto
# Yudiwanti Wahyu Endro Kusumo
# Yuliana Maria Diah Ratnadewi
# Yulin Lestari
#          id                             name        NIDN  \
# 0   6186794              ABDUL HARIS MUSTARI  0015106508
# 0   5996964                ACHMAD FARAJALLAH  0027046503
# 0   6000226               AGUS GHAUTSUN NIAM  0011068206
# 0   6038006                      AGUS HIKMAT  0018096208
# 0   5985693             AGUS PRIYONO KARTONO  0021026609
# ..      ...                              ...         ...
# 0   6165395  YOHANA CAECILIA SULISTYANINGSIH  0011056209
# 0     36148            YOHANES ARIS PURWANTO  0007036406
# 0   5988733     YUDIWANTI WAHYU ENDRO KUSUMO  0007116311
# 0   5976282     YULIANA MARIA DIAH RATNADEWI  0026035706
# 0   5982915                    YULIN LESTARI  0010076212
#
#                  affiliation  \
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# ..                       ...
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
# 0   Institut Pertanian Bogor
#
#                                                 areas
# 0                                 [Ekologi Satwaliar]
# 0                                           [Zoology]
# 0                             [Biosystem engineering]
# 0    [Plant Conservation, Plant Ecology, Ethnobotany]
# 0   [Biodiversity Conservation, Mammals Ecology, B...
# ..                                                ...
# 0   [Medicinal plant, Plant structure and histoche...
# 0   [food engineering, postharvest engineering, re...
# 0                                     [Pant Breeding]
# 0          [secondary metabolism in in vitro culture]
# 0                           [Microbial ecophysiology]
#
# [123 rows x 5 columns]

# %%
df1 = ALL.set_index('id', drop=False)
df2 = output_missing_NIDN.set_index('id', drop=False)

for _id in df2.index:
    #print(df1.loc[_id, :], _id)
    df1.loc[_id, 'NIDN'] = df2.loc[_id, 'NIDN'] 
    
'''df1 = df1.set_index('NIDN', drop=False)
df2 = output_missing_SINTAID.set_index('NIDN', drop=False)

for _id in df2.index:
    df1.loc[_id, 'id'] = df2.loc[_id, 'id']

'''
#df1.NIDN = [i.replace(' ','') for i in df1.NIDN]'''
df1 = df1[~df1.name.isnull()]
df1 = df1.reset_index(drop = True)
df1.to_csv(f'../tables/{affil_name}_bio_clean.csv')

# %%
df = pd.read_csv(f'../tables/{affil_name}_bio_clean.csv', index_col=0, dtype=str)
sinta_get = sinta.authors(df.id)
df2 = pd.DataFrame(sinta_get)
df2.to_csv(f'../tables/{affil_name}_bio_clean_sinta.csv')
df2 = pd.read_csv(f'../tables/{affil_name}_bio_clean_sinta.csv', index_col=0, dtype=str)
df = df.merge(df2, left_on='id', right_on='id')#2.set_index('id', drop=False)
df['Instansi'] = affil_name_long
df.to_csv(f'../tables/{affil_name}_bio_ready.csv')
